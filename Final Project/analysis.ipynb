# %% [markdown]
# # DS3000B — Canadian Households Housing Burden
#
# **Course:** DS 3000B — Introduction to Machine Learning
# **Assignment:** Coursework — Canadian Households Housing Burden
# **Word Count:** TBD

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

import warnings
warnings.filterwarnings('ignore')

SEED = 42
np.random.seed(SEED)

# %% [markdown]
# ## 1. Data Preparation

# %% [markdown]
# ### 1a. Load & Filter to PRCDDA

# %% [markdown]
# ### 1b. Build Target Variable (HBR) & Drop Leakage

# %% [markdown]
# ### 1c. Construct Tableau (Clean Features)

# %% [markdown]
# ## 2. Unsupervised Learning

# %% [markdown]
# ### 2a. EDA — Train/Test Split, Standardisation, Target Distribution, Correlations

# %% [markdown]
# ### 2b. K-Means Clustering

# %% [markdown]
# ### 2c. PCA

# %% [markdown]
# ### 2d. UMAP

# %% [markdown]
# ## 3. Supervised Learning

# %% [markdown]
# ### 3a. Elastic-Net GLM (PT3 Transform)

# %% [markdown]
# ### 3b. XGBoost

# %% [markdown]
# ### 3c. SHAP Explainer
